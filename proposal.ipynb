# %% [markdown]
# **Proposal DCD - Reynaldi Gevin**

# %% [markdown]
# # Background
#
# Berdasarkan Kamus Besar Bahasa Indonesia (KBBI), komunikasi adalah pengiriman dan penerimaan pesan atau berita antara dua orang atau lebih sehingga pesan yang dimaksud dapat dipahami. Komunikasi bertujuan untuk membuat komunikan (penerima informasi) menunjukkan perubahan sikap, perubahan pendapat, perubahan perilaku, dan perubahan partisipasi sosial. Penyampaian pesan kepada komunikan dapat dilakukan dengan cara bertemu langsung/tatap muka atau juga dengan menggunakan saluran atau *channel* seperti tv, radio, film, dan sebagainya. Komunikasi mengambil peran peting dalam setiap aspek bisnis, seperti manajemen, keuangan, legalitas, pemasaran, dan penjualan.
#
# Beberapa tahun terakhir kita dihebohkan dengan fenomena yang melanda di seluruh dunia. Senin, 2 Maret 2020, merupakan hari dimana Presiden Joko Widodo mengumumkan secara resmi kasus pertama virus Covid-19 terjadi di Indonesia. Sejak saat itu semua kegiatan tatap muka ditiadakan demi menekan angka penyebaran virus Covid-19 dan digantikan dengan menggunakan media online sebagai sarana dalam berkomunikasi. Hal ini menyebabkan pengguna media video conference meningkat secara drastis ditahun 2020.
#
# <img src="https://149371380.v2.pressablecdn.com/wp-content/uploads/2021/04/Microsoft-Teams-daily-active-users.webp"  width="500" height="600">
#
# **Source: Tom Talks - Microsoft Teams Statistics**
#
# Banyak perusahaan beralih dari sebelumnya melakukan rapat dikantor sekarang menggunakan platform video conference tertentu dalam menjalankan kegiatan bisnisnya. Bicara tentang bisnis, aspek pemasaran (*marketing*) dan penjualan (*sales*) merupakan salah satu aspek yang mengambil peranan yang sangat penting. Tim marketing berupaya untuk mencari tahu apa yang diinginkan pasar kemudian menawarkan produknya, biasanya tim marketing akan melakukan market research terlebih dahulu sebelum meluncurkan suatu campaign atau penawaran produk. Tim sales berupaya untuk menjual produk atau jasa yang telah dirancang perusahaan, agar dibeli dan digunakan pelanggan dalam rangka memenuhi kebutuhannya, biasanya tim sales akan menggunakan pilihan kata yang menarik agar produk yang ditawarkan dapat terjual.
#
# Salah satu indikator dari keberhasilan kedua aspek ini adalah respon atau feedback dari pasar atau konsumen apakah mereka tertarik dengan campaign atau produk yang ditawarkan. Secara tradisional perusahaan biasanya melakukan survei tertulis atau meminta feedback untuk mengetahui apa yang dibutuhkan konsumen dan apakah konsumen tertarik dengan produk yang ditawarkan. Bagaimanapun,metode ini mengasumsikan bahwa preferensi yang dituliskan adalah benar dan mencerminkan tindakannya di masa depan, akan tetapi hal ini tidak selalu terjadi. Terkadang keputusan konsumen bisa sangat berbeda dengan feedback yang diberikan ke perusahaan, karena adanya faktor personal yang menjadi pertimbangan konsumen terhadap campaign atau produk yang ditawarkan. Selain itu juga dibutuhkan waktu bagi konsumen mengisi feedback sampai mengirimkannya kembali ke perusahaan. Terkait dengan problem tersebut dibutuhkan suatu metode penarikan feedback yang lain untuk nantinya dapat di aplikasikan dalam proses bisnis suatu perusahaan.
#
# Banyak dari campaign dan penawaran produk pemasaran yang sukses berfokus pada memunculkan emosi konsumennya, hal ini menandakan bahwa perusahaan terhubung dengan audiens mereka. Memanfaatkan teknologi deteksi emosi untuk memahami emosi pelanggan dalam memahami produk yang ditawarkan adalah salah satu solusi dari permasalahan yang diutarakan di paragraf sebelumnya. Pendeteksian emosi wajah adalah teknologi yang digunakan untuk menganalisis sentimen dar berbagai sumber seperti gambar dan video. Teknologi deteksi emosi sangatlah bermanfaat dalam dunia bisnis. Untuk tim marketing teknologi ini dapat membantu dalam memilih campaign yang paling diminati oleh pasar hingga akhirnya produk tersebut dipasarkan secara luas, sedangkan untuk tim sales teknologi ini dapat membantuk untuk menyesuaikan teknik pemasaran secara dinamis berdasarkan respon real time dari konsumen terhadap produk yang ditawarkan. Selain itu juga pemasaran dan pengambilan feedback tidak lagi dilakukan secara door to door melainkan dapat dilakukan dengan lebih mudah dan cepat karena hanya bermodalkan internet dan gadget untuk menjalankannya.

# %% [markdown]
# # Problem Statement
#
# Untuk mengidentifikasi ekspresi wajah seseorang saat mengikuti campaign atau penawaran produk tertentu melalui video conference dan menilai apakah orang tersebut tertarik dengan penawaran yang diberikan atau tidak. Analisa ekspresi dimanfaatkan agar perusahaan mendapatkan feedback secara realtime terkait penawaran yang diberikan.
#
# Adanya project ini dapat membantu meningkatkan efisiensi biaya marketing karena project ini dapat melakukan pra-evaluasi terhadap campaign-campaign yang akan diluncurkan. Dipastikan bahwa campaign yang terpilih adalah campaign yang menghasilkan dampak atau ekspresi positif yang paling banyak. Dengan mengetahui sebenarnya campign atau produk manakah yang paling disukai oleh pasar, maka perusahaan tidak perlu lagi mengeksekusi semua marketing plan yang sudah di buat yang dimana membutuhkan biaya yang lebih besar.

# %% [markdown]
# # Project Idea
#
# Ide dari masalah yang ada adalah membuat suatu model machine learning yang dapat mendeteksi dan mengklasifikasi ekpresi wajah dari seseorang saat mengikuti video conference penawaran produk jasa atau barang. Hasil klasifikasi ekspresi yang didapatkan kemudian dimanfaatkan sebagai feedback real time dari konsumen terhadap produk yang ditawarkan. Feedback tersebut digunakan sebagai pertimbangan untuk mengambil keputusan dalam menentukan campaign yang akan dipasarkan secara luas, selain itu feedback tersebut juga bermanfaat untuk seorang sales agar dapat beradaptasi secara dinamis terhadap respon realtime yang didapatkan dari calon konsumennya, dalam upaya agar produk yang ditawarkan dapat terjual.

# %% [markdown]
# # Problem Scope
#
# Pada project ini akan digunakan sebuah data ekspresi wajah yang terbagi atas 7 jenis ekspresi. Data ini diambil dari Kaggle dengan judul "Facial Expression Recognition 2013 (FER 2013)" Dataset ini berisi 2 folder yaitu train dan validation, namun dalam project ini hanya digunakan 5 ekspresi saja yaitu happy, sad, angry, neutral, surprise sedangkan 2 jenis lain yaitu disgust dan fear tidak dipakai karena menurut saya kedua ekspresi tersebut tidak relevan dengan permasalahan bisnis yang akan diselesaikan. Untuk modelnya sendiri akan dibuat sebuah model klasifikasi dengan memanfaatkan algoritma Convolutional Neural Network dan Computer Vision akan digunakan untuk sarana dalam menjalankan model yang sudah dibuat. Namun dalam project ini partisipan atau audiens yang akan dianalis terbatas dalam skala yang kecil yaitu maksimal 30 orang atau satu halaman layar platform meeting yang dipakai.

# %% [markdown]
# # Output
#
# Output dari project ini berupa dashboard yang akan menampilkan Exploratory Dataset yang digunakan dan menjalankan simulasi model machine learnig untuk emotion recognition. Ditampilkan juga analisis ekspresi dominan yang dihasilkan dari hasil simulasi tersebut.

# %% [markdown]
# # Business Impact
#
# Selain identifikasi ekspresi wajah untuk video conference, project ini juga bisa diaplikasikan dan dikembangkan lagi ke beberapa bidang yang ada di kehidupan kita seperti :
# - Otomotif : mendeteksi apakah pengemudi lelah atau stres berdasarkan ekspresi wajah mereka dan memberikan peringatan ketika pengemudi dalam kondisi yang  tidak aman berdasarkan ekspresi wajahnya
# - Pendidikan : menilai apakah siswa dapat memahami pelajaran yang diberikan berdasrkan ekspresi wajahnya selama dikelas
# - Kesehatan : mendeteksi wajah pasien di ruang tunggu, sehingga dapat memprioritaskan pasien untuk diberi perawatan terlebih dahulu berdasarkan ekspresi wajahnya
# - Rekrutmen : mendeteksi wajah pelamar menggunakan video saat wawancara sebagai tahap penyaringan awal calon pekerja
# - Gaming : menilai tingkat kepuasan user saat memainkan game tertentu

# %% [markdown]
# # Project

# %% [markdown]
# Apa itu emotion recognition ?
#
# Pengenalan emosi adalah proses mendeteksi emosi manusia yang ditampilkan dilayar komputer untuk mengevaluasi respons non-verbal terhadap produk, layanan, atau barang. Analisis emosi dapat dilakukan dengan menggunakan deteksi wajah atau teknologi pengenalan wajah yang memungkinkan program untuk "memeriksa" sentimen pada wajah manusia dengan memanfaatkan dispensasi gambar yang canggih. Ekspresi wajah umumnya dianalisis dengan menggunakan kamera untuk mendeteksi wajah dan menangkap respons manusia secara real-time terhadap skenario dunia nyata. Setiap ekspresi wajah yang ditampilkan individu menyebabkan otot-otot wajah bergerak dan berkontraksi secara berbeda, dan ini membuat proses penentuan emosi menjadi lebih mudah.
#
# Berikut merupakan proses EDA, mempersiapkan data, membangun arsitektur model, training model, dan evaluasi performa model.

# %% [markdown]
# ## Input Libraries

# %%
# Data manipulation
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import glob as gb

# %%
# Modelling
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D 
from keras.layers.convolutional import MaxPooling2D
import os
from tensorflow.keras.utils import img_to_array
import tensorflow as tf
from keras import regularizers

# %% [markdown]
# ## Read Data

# %% [markdown]
# Ada tujuh emosi universal yang diakui menurut psikolog Dr. Paul Ekman. Di bawah ini adalah tujuh emosi wajah (ekspresi wajah) yang umumnya terjadi.
#
# - `Bahagia` : Mengangkat alis dan sudut mulut
# - `Terkejut` : Alis terangkat tetapi tidak menyatu, kelopak mata atas terangkat, rahang turun
# - `Marah` : Alis ditarik ke bawah, mata terbuka lebar, bibir terkatup rapat
# - `Takut` : Rahang terbuka, bibir ditekan ke belakang secara horizontal, kelopak mata atas terangkat
# - `Sedih` : Mengerutkan kening dengan sudut bibir ditarik ke bawah, sudut bagian dalam alis disatukan, kelopak mata terkulai.
# - `Jijik` : Bibir atas terangkat dalam bentuk seperti 'u', alis diturunkan, kerutan hidung
# - `Netral` :Bibir horizontal, alis tidak terangkat, dan mata tidak terbuka lebar.
#
# Tetapi tidak semua ekspresi diatas akan dipakai dalam project ini, karena mempertimbangkan bahwa ekspresi takut dan jijik yang menurut penulis tidak terlalu relevan dengan bisnis problem yang diangkat terkait penawaran campaing atau produk

# %%
train_data_dir='D:/ALGORITMA/Emotion Recognition/face-expression-recognition-dataset/train'
validation_data_dir=r'D:\ALGORITMA\Emotion Recognition\face-expression-recognition-dataset\validation'

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Cek jumlah data
#
# Tahapan Eksploratori Data Analsis akan dimulai dengan mencari tahu berapa jumlah gambar yang terdapat di setiap kategori ekspresi yang ada di data train dan data validation yang sudah di input sebelumnya.

# %%
for folder in os.listdir(train_data_dir):
    files = gb.glob(pathname= str(train_data_dir+ '/'+ folder + '/*.jpg'))
    print(f'For training data, found {len(files)} in folder {folder}')
# Out:
# For training data, found 3993 in folder angry
# For training data, found 7164 in folder happy
# For training data, found 4982 in folder neutral
# For training data, found 4938 in folder sad
# For training data, found 3205 in folder surprise

# %%
for folder in os.listdir(validation_data_dir):
    files = gb.glob(pathname= str(validation_data_dir+ '/'+ folder + '/*.jpg'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 960 in folder angry
# For testing data, found 1825 in folder happy
# For testing data, found 1216 in folder neutral
# For testing data, found 1139 in folder sad
# For testing data, found 797 in folder surprise

# %%
def get_counts(path):
  emotions = os.listdir(path)

  cls_counts = {}
  for emotion in emotions:
    count = len(os.listdir(os.path.join(path, emotion)))
    # print(emotion, count)
    cls_counts[emotion] = count

  return cls_counts

train_counts = get_counts(train_data_dir)

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize = (14, 8))

explode = [0.05] * 5

## Pie for training
ax0.set_title('Train classes Pie chart')
ax0.pie(train_counts.values(), labels=train_counts.keys(),
        explode=explode, autopct='%1.1f%%', shadow=True)
ax1.set_title('Train classes Bar chart')
ax1.bar(train_counts.keys(), train_counts.values(), width=0.8)


fig.savefig(r'D:\ALGORITMA\Emotion Recognition\face-expression-recognition-dataset\Face-Emotion-Recognition-\img\persebaran.png')

plt.show()

# %% [markdown]
# ### Cek dimensi gambar
#
# Salah satu aspek penting dalam klasifikasi gambar adalah memahami dimensi dari gambar masukan. Kita perlu mengetahui ukuran dimensi gambar yang kita gunakan untuk membuat dimensi input yang tepat saat membangun model deep learning. Mari kita periksa dimensi dari gambar pertama.

# %%
import cv2  
# loading the image
imgg = cv2.imread(files[1])
  
# fetching the dimensions
wid = imgg.shape[1]
hgt = imgg.shape[0]
  
# displaying the dimensions
print(str(wid) + "x" + str(hgt))
# Out:
# 48x48

# %% [markdown]
# Data gambar yang kita punya memiliki dimensi 48x48 pixel

# %% [markdown]
# ### Cek spesifikasi gambar

# %% [markdown]
# Dengan bantuan library Pillow kita dapat melihat properti gambar, seperti dimensi, format gambar, dan apakah gambar kita berwarna atau hitam putih.

# %%
from PIL import Image 
im = Image.open(files[1]) 
print(im.format, im.size, im.mode) 

# Based on documentation https://pillow.readthedocs.io/en/stable/handbook/concepts.html#concept-modes
# L (8-bit pixels, black and white)
# 8-bit pixel has a range of 0-255
# Out:
# JPEG (48, 48) L

# %% [markdown]
# Dapat dilihat bahwa data gambar yang kita punya berformat JPEG dengan dimensi 48x48 pixel dan modenya hitam putih (greyscale)
# Berdasrkan dokumentasi [Pillow 9.2.0](https://pillow.readthedocs.io/en/stable/handbook/concepts.html#concept-modes) bahwa mode `L` merupakan hitam-putih dengan range 0-255

# %% [markdown]
# ### Menampilkan gambar tiap jenis emosi

# %%
expression='angry'
pic_size=48
plt.figure(figsize=(20,20))
for i in range(1,19,1):
    plt.subplot(6,6,i)
    img= tf.keras.preprocessing.image.load_img(train_data_dir+'/'+expression+"/"+
                os.listdir(train_data_dir+'/'+ expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %%
expression='happy'
pic_size=48
plt.figure(figsize=(20,20))
for i in range(1,19,1):
    plt.subplot(6,6,i)
    img= tf.keras.preprocessing.image.load_img(train_data_dir+'/'+expression+"/"+
                os.listdir(train_data_dir+'/'+ expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %%
expression='neutral'
pic_size=48
plt.figure(figsize=(20,20))
for i in range(1,19,1):
    plt.subplot(6,6,i)
    img= tf.keras.preprocessing.image.load_img(train_data_dir+'/'+expression+"/"+
                os.listdir(train_data_dir+'/'+ expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %%
expression='sad'
pic_size=48
plt.figure(figsize=(20,20))
for i in range(1,19,1):
    plt.subplot(6,6,i)
    img= tf.keras.preprocessing.image.load_img(train_data_dir+'/'+expression+"/"+
                os.listdir(train_data_dir+'/'+ expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %%
expression='surprise'
pic_size=48
plt.figure(figsize=(20,20))
for i in range(1,19,1):
    plt.subplot(6,6,i)
    img= tf.keras.preprocessing.image.load_img(train_data_dir+'/'+expression+"/"+
                os.listdir(train_data_dir+'/'+ expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Data Preprocessing
# Pra-pemrosesan data untuk gambar cukup sederhana dan dapat dilakukan dalam satu langkah sebagai berikut.

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# Karena kita hanya memiliki sedikit data gambar untuk di training, maka akan dibentuk data buatan menggunakan metode yang disebut dengan Image Augmentation. Image Augmentation adalah salah satu teknik yang berguna dalam membangun model yang diaman dapat meningkatkan jumlah data training tanpa perlu mencari atau menginput gambar baru. Tujuannya adalah untuk mengajarkan model tidak hanya dengan gambar asli tetapi juga modifikasi gambar, seperti membalik gambar, memutar gambar, memperbesar, memotong gambar, dll. Ini akan membuat model menjadi lebih baik dalam mengidentifikasi gambar. Untuk melakukan image augmentation kita menggunakan generator data gambar dengan bantuan Keras.

# %%
# initial image spesification
num_classes =5
img_rows,img_cols = 48,48
batch_size=64 # how many image will train at once

# %% [markdown]
# Sebelum melakukan augmentasi perlu juga kita mengatur ukuran batch untuk data sehingga model akan diperbarui setiap kali selesai training untuk satu batch. Jumlah batch yang digunakan dalam model ini adalah 64.

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=30,
                                  shear_range=0.3,
                                  zoom_range=0.3,
                                  width_shift_range=0.4,
                                  height_shift_range=0.4,
                                  horizontal_flip=True,
                                  fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                   color_mode='grayscale',
                                                   target_size=(img_rows,img_cols),
                                                   batch_size=batch_size,
                                                   class_mode='categorical',
                                                   shuffle=True) #shuffle to every categorical class

validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                              color_mode='grayscale',
                                                              target_size=(img_rows,img_cols),
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              shuffle=True)
# Out:
# Found 24282 images belonging to 5 classes.
# Found 5937 images belonging to 5 classes.

# %% [markdown]
# Untuk melakukan augmentasi gambar, kita dapat memasukkan data gambar yang kita miliki ke dalam generator. Di sini, kita akan membuat generator gambar dengan ketentuan sebagai berikut :
#
# - Rescaling gambar menajdi 1/255
# - Merotasi gambar sebesar 30 drajat
# - Shearing gambar skala 0.3
# - Zooming gambar dengan range 0.3
# - Pergeseran lebar gambar dengan range 0.4
# - Pergeseran panjang gambar dengan range 0.4
# - Melakukan horizontal flip
# - Menggunakan fill mode nearest
#
# Jika ingin mengetahui lebih tentang bagaimana melakukan image augmentation menggunakan Keras dapat mengakses dokumentasi resminya [disini](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)

# %% [markdown]
# ## Design Architecture

# %% [markdown]
# Project ini menggunakan model CNN untuk medeteksi ekspresi wajah dari seseorang.

# %%
from keras.optimizers import RMSprop,SGD,Adam

model = Sequential()

#1st CNN layer
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', input_shape=(48, 48, 1)))

#2nd CNN layer
model.add(Conv2D(64,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#3rd CNN layer
model.add(Conv2D(128,(3,3),padding = 'same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))


#3rd CNN layer
model.add(Conv2D(256,(3,3),padding = 'same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))


model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(1024))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(num_classes, activation='softmax'))

opt = Adam(lr = 0.0001,decay=1e-6)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 24, 24, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 24, 24, 256)       0
#
# ...

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
file_model='D:/ALGORITMA/Emotion Recognition/face-expression-recognition-dataset/Emotion_model_first.h5'

# %%
checkpoint = ModelCheckpoint(file_model,
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1)
earlystop = EarlyStopping(monitor='val_loss',
                         min_delta=0,
                         patience=8,
                         verbose=1,
                         restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                             factor=0.2,
                             patience=6,
                             verbose=1,
                             min_delta=0.0001)

callbacks = [earlystop,checkpoint,reduce_lr]

# %% [markdown]
# ## Fitting Model

# %%
epochs = 60
# history = model.fit_generator(train_generator,
#                              steps_per_epoch=train_generator.n // batch_size,
#                              epochs=epochs,
#                              callbacks=callbacks,
#                              validation_data=validation_generator,
#                              validation_steps=validation_generator.n // batch_size)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_29364\3795789050.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/60
# 379/379 [==============================] - ETA: 0s - loss: 4.1352 - accuracy: 0.2515
# Epoch 1: val_loss improved from inf to 3.75642, saving model to D:/ALGORITMA/Emotion Recognition/face-expression-recognition-dataset\Emotion_model_first.h5
# 379/379 [==============================] - 781s 2s/step - loss: 4.1352 - accuracy: 0.2515 - val_loss: 3.7564 - val_accuracy: 0.2403 - lr: 1.0000e-04
# Epoch 2/60
# 379/379 [==============================] - ETA: 0s - loss: 3.5154 - accuracy: 0.2635
# Epoch 2: val_loss improved from 3.75642 to 3.08670, saving model to D:/ALGORITMA/Emotion Recognition/face-expression-recognition-dataset\Emotion_model_first.h5
# ...

# %% [markdown]
# ## Plotting Accuracy & Loss

# %%
# Checking the train and test loss and accuracy values from the neural network above.

train_loss = history.history['loss']
test_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
test_accuracy = history.history['val_accuracy']

# %%
# Plotting a line chart to visualize the loss and accuracy values by epochs.

fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')

# %% [markdown]
# Dapat dilihat bahwa akurasi yang dihasilkan untuk data traing sebesar 55.62% dan untuk data validation sebesar 66.03 %
